# %% [markdown]
# # Task 1

# %% [markdown]
# # Consider the Excel file named 2 Pak imm.xlsx containing year-wise immigration data from Pakistan to other countries.
# The data includes the following columns:
#
# 1. Origin Country (constant value: ’Pakistan’)
# 2. Origin Country Latitude
# 3. Origin Country Longitude
# 4. Destination Region
# 4. Destination Country
# 5. Destination Country Latitude
# 6. Destination Country Longitude
# 7. Year
# 8. Number of Emigrants

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Pak = pd.read_excel("2_Pak_imm.xlsx")
Pak.head(10)
# Out:
#   Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0       Pakistan                30.375321                 69.345116
# 1       Pakistan                30.375321                 69.345116
# 2       Pakistan                30.375321                 69.345116
# 3       Pakistan                30.375321                 69.345116
# 4       Pakistan                30.375321                 69.345116
# 5       Pakistan                30.375321                 69.345116
# 6       Pakistan                30.375321                 69.345116
# 7       Pakistan                30.375321                 69.345116
# 8       Pakistan                30.375321                 69.345116
# 9       Pakistan                30.375321                 69.345116
#
#   Destination Region Destination Country  Dest. Country Latitude  \
# 0             Africa             Algeria               28.033886
# 1             Africa             Algeria               28.033886
# ...

# %%
Pak.head()
# Out:
#   Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0       Pakistan                30.375321                 69.345116
# 1       Pakistan                30.375321                 69.345116
# 2       Pakistan                30.375321                 69.345116
# 3       Pakistan                30.375321                 69.345116
# 4       Pakistan                30.375321                 69.345116
#
#   Destination Region Destination Country  Dest. Country Latitude  \
# 0             Africa             Algeria               28.033886
# 1             Africa             Algeria               28.033886
# 2             Africa             Algeria               28.033886
# 3             Africa             Algeria               28.033886
# 4             Africa             Algeria               28.033886
#
#    Dest. Country Longitude  Year  No. of Emigrants
# 0                 1.659626  1981                24
# 1                 1.659626  1982                23
# ...

# %%
Pak.tail()
# Out:
#      Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 2235       Pakistan                30.375321                 69.345116
# 2236       Pakistan                30.375321                 69.345116
# 2237       Pakistan                30.375321                 69.345116
# 2238       Pakistan                30.375321                 69.345116
# 2239       Pakistan                30.375321                 69.345116
#
#      Destination Region Destination Country  Dest. Country Latitude  \
# 2235             Africa              Zambia              -13.133897
# 2236             Africa              Zambia              -13.133897
# 2237             Africa              Zambia              -13.133897
# 2238             Africa              Zambia              -13.133897
# 2239             Africa              Zambia              -13.133897
#
#       Dest. Country Longitude  Year  No. of Emigrants
# 2235                27.849332  2019                32
# ...

# %%
Pak.shape
# Out:
# (2240, 9)

# %%
Pak.columns
# Out:
# Index(['Origin Country', 'Origin Country Latitude', 'Origin Country Longitude',
#        'Destination Region', 'Destination Country', 'Dest. Country Latitude',
#        'Dest. Country Longitude', 'Year', 'No. of Emigrants'],
#       dtype='object')

# %%
Pak.describe()
# Out:
#        Origin Country Latitude  Origin Country Longitude  \
# count             2.240000e+03               2240.000000
# mean              3.037532e+01                 69.345116
# std               7.107014e-15                  0.000000
# min               3.037532e+01                 69.345116
# 25%               3.037532e+01                 69.345116
# 50%               3.037532e+01                 69.345116
# 75%               3.037532e+01                 69.345116
# max               3.037532e+01                 69.345116
#
#        Dest. Country Latitude  Dest. Country Longitude         Year  \
# count             2227.000000              2227.000000  2240.000000
# mean                22.308234                33.974043  2002.036607
# std                 19.348100                40.873740    12.431554
# min                -30.559482               -95.712891  1981.000000
# 25%                  5.152149                 9.537499  1991.000000
# ...

# %%
Pak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Origin Country            2240 non-null   object
#  1   Origin Country Latitude   2240 non-null   float64
#  2   Origin Country Longitude  2240 non-null   float64
#  3   Destination Region        2240 non-null   object
#  4   Destination Country       2240 non-null   object
#  5   Dest. Country Latitude    2227 non-null   float64
#  6   Dest. Country Longitude   2227 non-null   float64
#  7   Year                      2240 non-null   int64
#  8   No. of Emigrants          2240 non-null   int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 157.6+ KB

# %%
Pak.isnull()
# Out:
#       Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0              False                    False                     False
# 1              False                    False                     False
# 2              False                    False                     False
# 3              False                    False                     False
# 4              False                    False                     False
# ...              ...                      ...                       ...
# 2235           False                    False                     False
# 2236           False                    False                     False
# 2237           False                    False                     False
# 2238           False                    False                     False
# 2239           False                    False                     False
#
#       Destination Region  Destination Country  Dest. Country Latitude  \
# ...

# %%
df_Pak = Pak.dropna()
df_Pak
# Out:
#      Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0          Pakistan                30.375321                 69.345116
# 1          Pakistan                30.375321                 69.345116
# 2          Pakistan                30.375321                 69.345116
# 3          Pakistan                30.375321                 69.345116
# 4          Pakistan                30.375321                 69.345116
# ...             ...                      ...                       ...
# 2235       Pakistan                30.375321                 69.345116
# 2236       Pakistan                30.375321                 69.345116
# 2237       Pakistan                30.375321                 69.345116
# 2238       Pakistan                30.375321                 69.345116
# 2239       Pakistan                30.375321                 69.345116
#
#      Destination Region Destination Country  Dest. Country Latitude  \
# ...

# %%
Df_country = df_Pak.groupby(['Destination Country']).sum()
Df_country
# Out:
#                                                          Origin Country  \
# Destination Country
# Algeria               PakistanPakistanPakistanPakistanPakistanPakist...
# Angola                PakistanPakistanPakistanPakistanPakistanPakist...
# Azerbaijan            PakistanPakistanPakistanPakistanPakistanPakist...
# Bahrain               PakistanPakistanPakistanPakistanPakistanPakist...
# Brunei                PakistanPakistanPakistanPakistanPakistanPakist...
# Cameroon              PakistanPakistanPakistanPakistanPakistanPakist...
# China                 PakistanPakistanPakistanPakistanPakistanPakist...
# Croatia               PakistanPakistanPakistanPakistanPakistanPakist...
# Cyprus                PakistanPakistanPakistanPakistanPakistanPakist...
# Gabon                 PakistanPakistanPakistanPakistanPakistanPakist...
# Gen-Island            PakistanPakistanPakistanPakistanPakistanPakist...
# Germany               PakistanPakistanPakistanPakistanPakistanPakist...
# ...

# %%
df_country = Pak.groupby(["Destination Country"]).sum()
df_country
# Out:
#                                                          Origin Country  \
# Destination Country
# Algeria               PakistanPakistanPakistanPakistanPakistanPakist...
# Angola                PakistanPakistanPakistanPakistanPakistanPakist...
# Azerbaijan            PakistanPakistanPakistanPakistanPakistanPakist...
# Bahrain               PakistanPakistanPakistanPakistanPakistanPakist...
# Brunei                PakistanPakistanPakistanPakistanPakistanPakist...
# Cameroon              PakistanPakistanPakistanPakistanPakistanPakist...
# China                 PakistanPakistanPakistanPakistanPakistanPakist...
# Croatia               PakistanPakistanPakistanPakistanPakistanPakist...
# Cyprus                PakistanPakistanPakistanPakistanPakistanPakist...
# Gabon                 PakistanPakistanPakistanPakistanPakistanPakist...
# Gen-Island            PakistanPakistanPakistanPakistanPakistanPakist...
# Germany               PakistanPakistanPakistanPakistanPakistanPakist...
# ...

# %%
df_origin = df_Pak.groupby(["Origin Country"]).sum()
df_origin
# Out:
#                 Origin Country Latitude  Origin Country Longitude  \
# Origin Country
# Pakistan                   67645.839867             154431.573332
#
#                                                Destination Region  \
# Origin Country
# Pakistan        AfricaAfricaAfricaAfricaAfricaAfricaAfricaAfri...
#
#                                               Destination Country  \
# Origin Country
# Pakistan        AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
#
#                 Dest. Country Latitude  Dest. Country Longitude     Year  \
# Origin Country
# Pakistan                  49680.438066             75660.192699  4458341
#
#                 No. of Emigrants
# Origin Country
# Pakistan                12049168

# %%
df_origin_latitudes = Pak.groupby(["Origin Country Latitude"]).sum()
df_origin_latitudes
# Out:
#                                                             Origin Country  \
# Origin Country Latitude
# 30.375321                PakistanPakistanPakistanPakistanPakistanPakist...
#
#                          Origin Country Longitude  \
# Origin Country Latitude
# 30.375321                            155333.05984
#
#                                                         Destination Region  \
# Origin Country Latitude
# 30.375321                AfricaAfricaAfricaAfricaAfricaAfricaAfricaAfri...
#
#                                                        Destination Country  \
# Origin Country Latitude
# 30.375321                AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
#
#                          Dest. Country Latitude  Dest. Country Longitude  \
# Origin Country Latitude
# 30.375321                          49680.438066             75660.192699
#
#                             Year  No. of Emigrants
# Origin Country Latitude
# ...

# %%
df_origin_longitudes = Pak.groupby(["Origin Country Longitude"]).sum()
df_origin_longitudes
# Out:
#                                                              Origin Country  \
# Origin Country Longitude
# 69.345116                 PakistanPakistanPakistanPakistanPakistanPakist...
#
#                           Origin Country Latitude  \
# Origin Country Longitude
# 69.345116                             68040.71904
#
#                                                          Destination Region  \
# Origin Country Longitude
# 69.345116                 AfricaAfricaAfricaAfricaAfricaAfricaAfricaAfri...
#
#                                                         Destination Country  \
# Origin Country Longitude
# 69.345116                 AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
#
#                           Dest. Country Latitude  Dest. Country Longitude  \
# Origin Country Longitude
# 69.345116                           49680.438066             75660.192699
#
#                              Year  No. of Emigrants
# Origin Country Longitude
# ...

# %%
df_destination_region = Pak.groupby(["Destination Region"]).sum()
df_destination_region
# Out:
#                                                        Origin Country  \
# Destination Region
# Africa              PakistanPakistanPakistanPakistanPakistanPakist...
# Central Asia        PakistanPakistanPakistanPakistanPakistanPakist...
# East Asia           PakistanPakistanPakistanPakistanPakistanPakist...
# Europe              PakistanPakistanPakistanPakistanPakistanPakist...
# Middle East         PakistanPakistanPakistanPakistanPakistanPakist...
# North America       PakistanPakistanPakistanPakistanPakistanPakist...
# Others              PakistanPakistanPakistanPakistanPakistanPakist...
# Southeast Asia      PakistanPakistanPakistanPakistanPakistanPakist...
#
#                     Origin Country Latitude  Origin Country Longitude  \
# Destination Region
# Africa                         23510.498454              53673.119784
# Central Asia                    1306.138803               2981.839988
# East Asia                       5224.555212              11927.359952
# ...

# %%
df_destination_country = Pak.groupby(["Destination Country"]).sum()
df_destination_country
# Out:
#                                                          Origin Country  \
# Destination Country
# Algeria               PakistanPakistanPakistanPakistanPakistanPakist...
# Angola                PakistanPakistanPakistanPakistanPakistanPakist...
# Azerbaijan            PakistanPakistanPakistanPakistanPakistanPakist...
# Bahrain               PakistanPakistanPakistanPakistanPakistanPakist...
# Brunei                PakistanPakistanPakistanPakistanPakistanPakist...
# Cameroon              PakistanPakistanPakistanPakistanPakistanPakist...
# China                 PakistanPakistanPakistanPakistanPakistanPakist...
# Croatia               PakistanPakistanPakistanPakistanPakistanPakist...
# Cyprus                PakistanPakistanPakistanPakistanPakistanPakist...
# Gabon                 PakistanPakistanPakistanPakistanPakistanPakist...
# Gen-Island            PakistanPakistanPakistanPakistanPakistanPakist...
# Germany               PakistanPakistanPakistanPakistanPakistanPakist...
# ...

# %%
df_destination_country_latitudes = Pak.groupby(["Dest. Country Latitude"]).sum()
df_destination_country_latitudes
# Out:
#                                                            Origin Country  \
# Dest. Country Latitude
# -30.559482              PakistanPakistanPakistanPakistanPakistanPakist...
# -13.133897              PakistanPakistanPakistanPakistanPakistanPakist...
# -11.202692              PakistanPakistanPakistanPakistanPakistanPakist...
# -6.369028               PakistanPakistanPakistanPakistanPakistanPakist...
# -0.803689               PakistanPakistanPakistanPakistanPakistanPakist...
# -0.023559               PakistanPakistanPakistanPakistanPakistanPakist...
#  0.000000               PakistanPakistanPakistanPakistanPakistanPakist...
#  1.352083               PakistanPakistanPakistanPakistanPakistanPakist...
#  1.373333               PakistanPakistanPakistanPakistanPakistanPakist...
#  4.210484               PakistanPakistanPakistanPakistanPakistanPakist...
#  4.535277               PakistanPakistanPakistanPakistanPakistanPakist...
# ...

# %%
df_destination_country_longitudes = Pak.groupby(["Dest. Country Longitude"]).sum()
df_destination_country_longitudes
# Out:
#                                                             Origin Country  \
# Dest. Country Longitude
# -95.712891               PakistanPakistanPakistanPakistanPakistanPakist...
# -11.779889               PakistanPakistanPakistanPakistanPakistanPakist...
# -9.696645                PakistanPakistanPakistanPakistanPakistanPakist...
# -7.092620                PakistanPakistanPakistanPakistanPakistanPakist...
# -3.749220                PakistanPakistanPakistanPakistanPakistanPakist...
# -3.435973                PakistanPakistanPakistanPakistanPakistanPakist...
# -2.460415                PakistanPakistanPakistanPakistanPakistanPakist...
#  0.000000                PakistanPakistanPakistanPakistanPakistanPakist...
#  1.659626                PakistanPakistanPakistanPakistanPakistanPakist...
#  8.227512                PakistanPakistanPakistanPakistanPakistanPakist...
#  8.675277                PakistanPakistanPakistanPakistanPakistanPakist...
# ...

# %%
df_year = Pak.groupby(["Year"]).sum()
df_year
# Out:
#                                          Origin Country  \
# Year
# 1981  PakistanPakistanPakistanPakistanPakistanPakist...
# 1982  PakistanPakistanPakistanPakistanPakistanPakist...
# 1983  PakistanPakistanPakistanPakistanPakistanPakist...
# 1984  PakistanPakistanPakistanPakistanPakistanPakist...
# 1985  PakistanPakistanPakistanPakistanPakistanPakist...
# 1986  PakistanPakistanPakistanPakistanPakistanPakist...
# 1987  PakistanPakistanPakistanPakistanPakistanPakist...
# 1988  PakistanPakistanPakistanPakistanPakistanPakist...
# 1989  PakistanPakistanPakistanPakistanPakistanPakist...
# 1990  PakistanPakistanPakistanPakistanPakistanPakist...
# 1991  PakistanPakistanPakistanPakistanPakistanPakist...
# 1992  PakistanPakistanPakistanPakistanPakistanPakist...
# 1993  PakistanPakistanPakistanPakistanPakistanPakist...
# 1994  PakistanPakistanPakistanPakistanPakistanPakist...
# 1995  PakistanPakistanPakistanPakistanPakistanPakist...
# 1996  PakistanPakistanPakistanPakistanPakistanPakist...
# ...

# %%
df_number_emigrants = Pak.groupby(["No. of Emigrants"]).sum()
df_number_emigrants
# Out:
#                                                      Origin Country  \
# No. of Emigrants
# 0                 PakistanPakistanPakistanPakistanPakistanPakist...
# 1                 PakistanPakistanPakistanPakistanPakistanPakist...
# 2                 PakistanPakistanPakistanPakistanPakistanPakist...
# 3                 PakistanPakistanPakistanPakistanPakistanPakist...
# 4                 PakistanPakistanPakistanPakistanPakistanPakist...
# ...                                                             ...
# 350522                                                     Pakistan
# 358560                                                     Pakistan
# 462598                                                     Pakistan
# 514909                                                     Pakistan
# 522750                                                     Pakistan
#
#                   Origin Country Latitude  Origin Country Longitude  \
# No. of Emigrants
# ...

# %% [markdown]
# # PART 2
# # Perform the following tasks:
# 1. Load the Excel file into a Pandas DataFrame.
# 2. Display the first few rows of the DataFrame.
# 3. Display the last few rows of the DataFrame.
# 4. Print the concise summary of the DataFrame.
# 5. Drop columns ’Origin Country’,’Origin Country Latitude’, ’Origin Country Longitude’, ’Destination Country Latitude’,
# and ’Destination Country Longitude’ from the DataFrame, and display the updated DataFrame.

# %%
df_excel = pd.read_excel("2_Pak_imm.xlsx")
df_excel
# Out:
#      Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0          Pakistan                30.375321                 69.345116
# 1          Pakistan                30.375321                 69.345116
# 2          Pakistan                30.375321                 69.345116
# 3          Pakistan                30.375321                 69.345116
# 4          Pakistan                30.375321                 69.345116
# ...             ...                      ...                       ...
# 2235       Pakistan                30.375321                 69.345116
# 2236       Pakistan                30.375321                 69.345116
# 2237       Pakistan                30.375321                 69.345116
# 2238       Pakistan                30.375321                 69.345116
# 2239       Pakistan                30.375321                 69.345116
#
#      Destination Region Destination Country  Dest. Country Latitude  \
# ...

# %%
df_excel.head(10)
# Out:
#   Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0       Pakistan                30.375321                 69.345116
# 1       Pakistan                30.375321                 69.345116
# 2       Pakistan                30.375321                 69.345116
# 3       Pakistan                30.375321                 69.345116
# 4       Pakistan                30.375321                 69.345116
# 5       Pakistan                30.375321                 69.345116
# 6       Pakistan                30.375321                 69.345116
# 7       Pakistan                30.375321                 69.345116
# 8       Pakistan                30.375321                 69.345116
# 9       Pakistan                30.375321                 69.345116
#
#   Destination Region Destination Country  Dest. Country Latitude  \
# 0             Africa             Algeria               28.033886
# 1             Africa             Algeria               28.033886
# ...

# %%
df_excel.tail(10)
# Out:
#      Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 2230       Pakistan                30.375321                 69.345116
# 2231       Pakistan                30.375321                 69.345116
# 2232       Pakistan                30.375321                 69.345116
# 2233       Pakistan                30.375321                 69.345116
# 2234       Pakistan                30.375321                 69.345116
# 2235       Pakistan                30.375321                 69.345116
# 2236       Pakistan                30.375321                 69.345116
# 2237       Pakistan                30.375321                 69.345116
# 2238       Pakistan                30.375321                 69.345116
# 2239       Pakistan                30.375321                 69.345116
#
#      Destination Region Destination Country  Dest. Country Latitude  \
# 2230             Africa              Zambia              -13.133897
# ...

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Origin Country            2240 non-null   object
#  1   Origin Country Latitude   2240 non-null   float64
#  2   Origin Country Longitude  2240 non-null   float64
#  3   Destination Region        2240 non-null   object
#  4   Destination Country       2240 non-null   object
#  5   Dest. Country Latitude    2227 non-null   float64
#  6   Dest. Country Longitude   2227 non-null   float64
#  7   Year                      2240 non-null   int64
#  8   No. of Emigrants          2240 non-null   int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 157.6+ KB

# %%
df_updated = df_excel.dropna()
df_updated
# Out:
#      Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0          Pakistan                30.375321                 69.345116
# 1          Pakistan                30.375321                 69.345116
# 2          Pakistan                30.375321                 69.345116
# 3          Pakistan                30.375321                 69.345116
# 4          Pakistan                30.375321                 69.345116
# ...             ...                      ...                       ...
# 2235       Pakistan                30.375321                 69.345116
# 2236       Pakistan                30.375321                 69.345116
# 2237       Pakistan                30.375321                 69.345116
# 2238       Pakistan                30.375321                 69.345116
# 2239       Pakistan                30.375321                 69.345116
#
#      Destination Region Destination Country  Dest. Country Latitude  \
# ...

# %%
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2227 entries, 0 to 2239
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Origin Country            2227 non-null   object
#  1   Origin Country Latitude   2227 non-null   float64
#  2   Origin Country Longitude  2227 non-null   float64
#  3   Destination Region        2227 non-null   object
#  4   Destination Country       2227 non-null   object
#  5   Dest. Country Latitude    2227 non-null   float64
#  6   Dest. Country Longitude   2227 non-null   float64
#  7   Year                      2227 non-null   int64
#  8   No. of Emigrants          2227 non-null   int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 174.0+ KB

# %%
df_updated.columns
# Out:
# Index(['Origin Country', 'Origin Country Latitude', 'Origin Country Longitude',
#        'Destination Region', 'Destination Country', 'Dest. Country Latitude',
#        'Dest. Country Longitude', 'Year', 'No. of Emigrants'],
#       dtype='object')

# %%
updated = df_excel.drop(['Origin Country', 'Origin Country Latitude', 'Origin Country Longitude', 'Dest. Country Latitude', 'Dest. Country Longitude'], axis=1)
updated.head(10)
# Out:
#   Destination Region Destination Country  Year  No. of Emigrants
# 0             Africa             Algeria  1981                24
# 1             Africa             Algeria  1982                23
# 2             Africa             Algeria  1983                20
# 3             Africa             Algeria  1984                15
# 4             Africa             Algeria  1985                13
# 5             Africa             Algeria  1986                10
# 6             Africa             Algeria  1987                11
# 7             Africa             Algeria  1988                13
# 8             Africa             Algeria  1989                16
# 9             Africa             Algeria  1990                19

# %%
updated.tail(10)
# Out:
#      Destination Region Destination Country  Year  No. of Emigrants
# 2230             Africa              Zambia  2014                20
# 2231             Africa              Zambia  2015                12
# 2232             Africa              Zambia  2016                20
# 2233             Africa              Zambia  2017                19
# 2234             Africa              Zambia  2018                17
# 2235             Africa              Zambia  2019                32
# 2236             Africa              Zambia  2020                18
# 2237             Africa              Zambia  2021                24
# 2238             Africa              Zambia  2022                28
# 2239             Africa              Zambia  2023                 7

# %%
updated.columns
# Out:
# Index(['Destination Region', 'Destination Country', 'Year',
#        'No. of Emigrants'],
#       dtype='object')

# %%
updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Destination Region   2240 non-null   object
#  1   Destination Country  2240 non-null   object
#  2   Year                 2240 non-null   int64
#  3   No. of Emigrants     2240 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 70.1+ KB

# %%
updated.shape
# Out:
# (2240, 4)

# %%
updated.describe()
# Out:
#               Year  No. of Emigrants
# count  2240.000000       2240.000000
# mean   2002.036607       5379.415625
# std      12.431554      31804.424927
# min    1981.000000          0.000000
# 25%    1991.000000          5.000000
# 50%    2002.000000         25.000000
# 75%    2013.000000        271.000000
# max    2023.000000     522750.000000

# %%
df_updated = df_excel.dropna()
df_updated.head(10)
# Out:
#   Origin Country  Origin Country Latitude  Origin Country Longitude  \
# 0       Pakistan                30.375321                 69.345116
# 1       Pakistan                30.375321                 69.345116
# 2       Pakistan                30.375321                 69.345116
# 3       Pakistan                30.375321                 69.345116
# 4       Pakistan                30.375321                 69.345116
# 5       Pakistan                30.375321                 69.345116
# 6       Pakistan                30.375321                 69.345116
# 7       Pakistan                30.375321                 69.345116
# 8       Pakistan                30.375321                 69.345116
# 9       Pakistan                30.375321                 69.345116
#
#   Destination Region Destination Country  Dest. Country Latitude  \
# 0             Africa             Algeria               28.033886
# 1             Africa             Algeria               28.033886
# ...

# %% [markdown]
# # Task 2

# %% [markdown]
# After dropping the specified columns, the DataFrame should now contain the following columns:
# • Destination Region
# • Destination Country
# • Year
# • No. of Emigrants

# %%
df_updated = df_excel.drop(['Origin Country', 'Origin Country Latitude', 'Origin Country Longitude', 'Dest. Country Latitude', 'Dest. Country Longitude'], axis=1)
df_updated.head(10)
# Out:
#   Destination Region Destination Country  Year  No. of Emigrants
# 0             Africa             Algeria  1981                24
# 1             Africa             Algeria  1982                23
# 2             Africa             Algeria  1983                20
# 3             Africa             Algeria  1984                15
# 4             Africa             Algeria  1985                13
# 5             Africa             Algeria  1986                10
# 6             Africa             Algeria  1987                11
# 7             Africa             Algeria  1988                13
# 8             Africa             Algeria  1989                16
# 9             Africa             Algeria  1990                19

# %%
df_updated.tail(10)
# Out:
#      Destination Region Destination Country  Year  No. of Emigrants
# 2230             Africa              Zambia  2014                20
# 2231             Africa              Zambia  2015                12
# 2232             Africa              Zambia  2016                20
# 2233             Africa              Zambia  2017                19
# 2234             Africa              Zambia  2018                17
# 2235             Africa              Zambia  2019                32
# 2236             Africa              Zambia  2020                18
# 2237             Africa              Zambia  2021                24
# 2238             Africa              Zambia  2022                28
# 2239             Africa              Zambia  2023                 7

# %% [markdown]
# # Part 2
# Perform the following tasks:
# 1. Display the first few rows of the updated DataFrame
# 2. Display the last few rows of the updated DataFrame.
# 3. Print the concise summary of the updated DataFrame.
# 4. Calculate and display the mean, median, and standard deviation of the ’No. of Emigrants’ column.
# 5. Calculate and display the total number of rows in the DataFrame.
# 6. Calculate and display the total number of cells (entries) in the DataFrame.
# 7. Identify and display the unique values in the ’Destination Region’ column.
# 8. Display the count of each unique value in the ’Destination Region’ column.
# 9. Identify and display the data types of each column in the DataFrame.
# 10. Inspect and display the descriptive statistics of the ’Year’ column.

# %%
df_updated.head(10)
# Out:
#   Destination Region Destination Country  Year  No. of Emigrants
# 0             Africa             Algeria  1981                24
# 1             Africa             Algeria  1982                23
# 2             Africa             Algeria  1983                20
# 3             Africa             Algeria  1984                15
# 4             Africa             Algeria  1985                13
# 5             Africa             Algeria  1986                10
# 6             Africa             Algeria  1987                11
# 7             Africa             Algeria  1988                13
# 8             Africa             Algeria  1989                16
# 9             Africa             Algeria  1990                19

# %%
df_updated.tail(10)
# Out:
#      Destination Region Destination Country  Year  No. of Emigrants
# 2230             Africa              Zambia  2014                20
# 2231             Africa              Zambia  2015                12
# 2232             Africa              Zambia  2016                20
# 2233             Africa              Zambia  2017                19
# 2234             Africa              Zambia  2018                17
# 2235             Africa              Zambia  2019                32
# 2236             Africa              Zambia  2020                18
# 2237             Africa              Zambia  2021                24
# 2238             Africa              Zambia  2022                28
# 2239             Africa              Zambia  2023                 7

# %%
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Destination Region   2240 non-null   object
#  1   Destination Country  2240 non-null   object
#  2   Year                 2240 non-null   int64
#  3   No. of Emigrants     2240 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 70.1+ KB

# %%
columns = "No. of Emigrants"
mu = df_updated[columns].mean()
mu
# Out:
# 5379.415625

# %%
median = df_updated[columns].median()
median
# Out:
# 25.0

# %%
std = df_updated[columns].std()
std
# Out:
# 31804.424927026048

# %%
rows = df_updated[columns].count()
rows
# Out:
# 2240

# %%
total_number= df_updated.size
total_number
# Out:
# 8960

# %%
# identify and display the unique values in the column 'Destination Country'
df_updated['Destination Country'].unique()
# Out:
# array(['Algeria', 'Angola', 'Azerbaijan', 'Bahrain', 'Brunei', 'Cameroon',
#        'China', 'Croatia', 'Cyprus', 'Gabon', 'Gen-Island', 'Germany',
#        'Greece', 'Guinea', 'Hong Kong', 'Iran', 'Iraq', 'Italy', 'Japan',
#        'Jordan', 'Kenya', 'Kuwait', 'Lebanon', 'Libya', 'Malaysia',
#        'Morocco', 'Nigeria', 'Oman', 'Others', 'Poland', 'Qatar',
#        'Romania', 'Saudi Arabia', 'Sierra Leone', 'Singapore', 'Somalia',
#        'South Africa', 'South Korea', 'Spain', 'Sudan', 'Sweden',
#        'Switzerland', 'Syria', 'Tanzania', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Uganda', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'West Africa', 'Yemen', 'Zambia'], dtype=object)

# %%
df_updated["Destination Country"].value_counts()
# Out:
# Destination Country
# Algeria                 43
# Nigeria                 43
# Others                  43
# Qatar                   43
# Saudi Arabia            43
# Sierra Leone            43
# Singapore               43
# Somalia                 43
# South Africa            43
# South Korea             43
# Spain                   43
# Sudan                   43
# Sweden                  43
# Switzerland             43
# Syria                   43
# Tanzania                43
# Tunisia                 43
# Turkey                  43
# Turkmenistan            43
# Uganda                  43
# United Arab Emirates    43
# United Kingdom          43
# United States           43
# West Africa             43
# Yemen                   43
# Angola                  43
# Oman                    43
# Morocco                 43
# Guinea                  43
# Azerbaijan              43
# Bahrain                 43
# Brunei                  43
# Cameroon                43
# ...

# %%
df_updated["Destination Region"].unique()
# Out:
# array(['Africa', 'Europe', 'Middle East', 'Southeast Asia', 'East Asia',
#        'Others', 'Central Asia', 'North America'], dtype=object)

# %%
df_updated["Destination Region"].value_counts()
# Out:
# Destination Region
# Africa            774
# Middle East       559
# Europe            434
# East Asia         172
# Southeast Asia    129
# Others             86
# Central Asia       43
# North America      43
# Name: count, dtype: int64

# %%
df_updated["Year"].unique()
# Out:
# array([1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#       dtype=int64)

# %%
updated["Year"].value_counts()
# Out:
# Year
# 2023    54
# 2022    54
# 2013    52
# 2005    52
# 2006    52
# 2007    52
# 2008    52
# 2009    52
# 2010    52
# 2011    52
# 2012    52
# 2014    52
# 2003    52
# 2015    52
# 2016    52
# 2017    52
# 2018    52
# 2019    52
# 2020    52
# 2021    52
# 2004    52
# 1981    52
# 1982    52
# 1991    52
# 1983    52
# 1984    52
# 1985    52
# 1986    52
# 1987    52
# 1988    52
# 1989    52
# 1990    52
# 1992    52
# 2001    52
# 1993    52
# 1994    52
# 1995    52
# 1996    52
# 1997    52
# 1998    52
# 1999    52
# 2000    52
# 2002    52
# Name: count, dtype: int64

# %%
df_updated["No. of Emigrants"].unique()
# Out:
# array([    24,     23,     20,     15,     13,     10,     11,     16,
#            19,     31,     25,     18,     17,     21,     35,     29,
#            30,     47,     71,     66,     60,      7,      2,     36,
#           211,    259,    461,    213,    118,      4,     14,      9,
#            12,     32,     48,     45,     41,      8,      6,      1,
#            22,      3,      0,     98,   2704,   2430,   2121,   1653,
#          1455,   1025,   1169,   1441,   1694,   2010,   2523,   3383,
#          2730,   1960,   2068,   2114,   2633,   1779,   1380,   1903,
#          2260,   2605,   3782,   3071,   2511,   3237,   5071,   7603,
#          7129,   6412,  10641,  10530,   9600,   9226,   9029,   8226,
#          7919,   5745,   8189,   7843,  12977,  13653,   3351,     26,
#            27,     28,     40,     34,     54,     80,     75,     68,
#            79,     74,     67,     85,    212,    225,    187,    202,
# ...

# %%
df_updated["No. of Emigrants"].value_counts()
# Out:
# No. of Emigrants
# 1       153
# 2        95
# 0        90
# 3        85
# 4        82
#        ...
# 5868      1
# 4798      1
# 6184      1
# 9690      1
# 382       1
# Name: count, Length: 749, dtype: int64

# %%
# indentify and display the data types of the columns
df_updated.dtypes
# Out:
# Destination Region     object
# Destination Country    object
# Year                    int64
# No. of Emigrants        int64
# dtype: object

# %%
df_updated["Destination Country"].describe()
# Out:
# count        2240
# unique         54
# top       Algeria
# freq           43
# Name: Destination Country, dtype: object

# %%
df_updated["Destination Region"].describe()
# Out:
# count       2240
# unique         8
# top       Africa
# freq         774
# Name: Destination Region, dtype: object

# %%
df_updated["No. of Emigrants"].describe()
# Out:
# count      2240.000000
# mean       5379.415625
# std       31804.424927
# min           0.000000
# 25%           5.000000
# 50%          25.000000
# 75%         271.000000
# max      522750.000000
# Name: No. of Emigrants, dtype: float64

# %%
# inspect and display the descriptive statistics of the year column

df_updated["Year"].describe()
# Out:
# count    2240.000000
# mean     2002.036607
# std        12.431554
# min      1981.000000
# 25%      1991.000000
# 50%      2002.000000
# 75%      2013.000000
# max      2023.000000
# Name: Year, dtype: float64

# %% [markdown]
# # Task 3

# %% [markdown]
# 1. How many Pakistanis emigrated from 1981 to 2023?
# 2. Identify and display the top 5 destination regions with the highest number of emigrants.
# 3. For the top destination region from the previous step, identify the unique countries within that region.
# 4. Calculate and display the total number of emigrants for each destination country.
# 5. Identify and display the destination country with the highest number of emigrants.
# 6. Calculate the percentage of total emigrants for each destination country and display the top 5 countries with the highest
# percentages.
# 7. Plot a bar chart showing the total number of emigrants for each destination region.
# 8. Plot a bar chart showing the total number of emigrants for the top 10 destination countries.
# 9. Plot a bar chart showing the total number of emigrants for the top 10 destination countries in Europe.
# 10. Plot a bar chart showing the total number of emigrants for the top 10 destination countries in South Asia.
# 11. Plot a bar chart showing the total number of emigrants for the top 10 destination countries in Africa

# %%
total_emigrants = df_updated["No. of Emigrants"].sum()
total_emigrants
# Out:
# 12049891

# %%
df_updated.groupby(["Destination Region"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Destination Region
# Middle East       11677230
# Southeast Asia      123541
# Africa               95155
# Europe               76018
# Others               40632
# East Asia            28604
# North America         7616
# Central Asia          1095
# Name: No. of Emigrants, dtype: int64

# %%
df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Destination Country
# Saudi Arabia            6056878
# United Arab Emirates    3950935
# Oman                     898368
# Qatar                    301038
# Bahrain                  200785
# Kuwait                   167925
# Malaysia                 120343
# Iraq                      74424
# Libya                     73302
# Others                    40457
# Name: No. of Emigrants, dtype: int64

# %%
df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Year
# 2015    946571
# 2016    839353
# 2022    832339
# 2014    752466
# 2012    638587
# 2019    625876
# 2013    622714
# 2017    496286
# 2011    456893
# 2008    430314
# Name: No. of Emigrants, dtype: int64

# %%
# For the top destination region from the previous step, identify the unique countries within that region.
top_destination_region = df_updated.groupby(["Destination Region"])["No. of Emigrants"].sum().sort_values(ascending=False).index[0]
unique_countries = df_updated[df_updated["Destination Region"] == top_destination_region]["Destination Country"].unique()
unique_countries
# Out:
# array(['Bahrain', 'Iran', 'Iraq', 'Jordan', 'Kuwait', 'Lebanon', 'Oman',
#        'Qatar', 'Saudi Arabia', 'Syria', 'Turkey', 'United Arab Emirates',
#        'Yemen'], dtype=object)

# %%
# calculate the total number of emigrants from each country within the top destination region

df_updated[df_updated["Destination Region"] == top_destination_region].groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Destination Country
# Saudi Arabia            6056878
# United Arab Emirates    3950935
# Oman                     898368
# Qatar                    301038
# Bahrain                  200785
# Kuwait                   167925
# Iraq                      74424
# Iran                      11645
# Jordan                     7906
# Yemen                      5218
# Name: No. of Emigrants, dtype: int64

# %%
# calculate the total number of emigrants from each country 
df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Destination Country
# Saudi Arabia            6056878
# United Arab Emirates    3950935
# Oman                     898368
# Qatar                    301038
# Bahrain                  200785
# Kuwait                   167925
# Malaysia                 120343
# Iraq                      74424
# Libya                     73302
# Others                    40457
# Name: No. of Emigrants, dtype: int64

# %%
# . Calculate the percentage of total emigrants for each destination country and display the top 5 countries with the highest percentages.
total_emigrants = df_updated["No. of Emigrants"].sum()
total_emigrants
# Out:
# 12049891

# %%
# calculate and display the total number of emigrants from each destination country
df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Destination Country
# Saudi Arabia            6056878
# United Arab Emirates    3950935
# Oman                     898368
# Qatar                    301038
# Bahrain                  200785
# Kuwait                   167925
# Malaysia                 120343
# Iraq                      74424
# Libya                     73302
# Others                    40457
# Name: No. of Emigrants, dtype: int64

# %%
# identify and display the destination country with the highest number of emigrants
highest_emigrants = df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).index[0]
highest_emigrants
# Out:
# 'Saudi Arabia'

# %%
# calculate the percentage of total emigrants for each destination country and display the top 5 countries with the highest percentages
df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10) / total_emigrants * 100
# Out:
# Destination Country
# Saudi Arabia            50.265002
# United Arab Emirates    32.788139
# Oman                     7.455404
# Qatar                    2.498263
# Bahrain                  1.666281
# Kuwait                   1.393581
# Malaysia                 0.998706
# Iraq                     0.617632
# Libya                    0.608321
# Others                   0.335746
# Name: No. of Emigrants, dtype: float64

# %%
# plot a bar chart showing the total number of emigrants from each destination country
df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10).plot(kind= "bar", figsize=(15,6), color = "green")
# Out:
# <Axes: xlabel='Destination Country'>

# %%
# plot a bar chart showing the total number of emigrants from each destination region
df_updated.groupby(["Destination Region"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10).plot(kind= "bar", figsize=(15,6), color = "green")
# Out:
# <Axes: xlabel='Destination Region'>

# %%
# plot a bar chart showing the total number of emigrants from top ten destination countries
df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10).plot(kind= "bar", figsize=(15,6), color = "green")
# Out:
# <Axes: xlabel='Destination Country'>

# %%
# plot a bar chart showing the total number of emigrants from top ten destination countries in Europe
df_updated[df_updated["Destination Region"] == "Europe"].groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10).plot(kind= "bar", figsize=(15,6),color = "green")
# Out:
# <Axes: xlabel='Destination Country'>

# %%
# plot a bar chart showing the total number of emigrants from top ten destination countries in Africa
df_updated[df_updated["Destination Region"] == "Africa"].groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10).plot(kind= "bar", figsize=(15,6),color = "green")
# Out:
# <Axes: xlabel='Destination Country'>

# %% [markdown]
# # Task 4:
# 1. Explore the unique values in the ’Year’ column.
# 2. Calculate and display the total number of emigrants for each year.
# 3. Identify and display the year with the highest number of emigrants.
# 4. Calculate the percentage of total emigrants for each year and display the top 3 years with the highest percentages.
# 5. Plot a line chart showing the trend of total emigrants over the years.
# 6. Explore and display any interesting patterns or insights you can find in the data regarding year-wise emigration.
# 7. For the year with the highest number of emigrants:
# (a) Identify and display the top 5 destination regions.
# (b) Identify and display the top 5 destination countries.
# 8. For the top destination region in the highest emigration year:
# (a) Calculate and display the total number of emigrants for each country within that region.
# (b) Identify and display the country with the highest number of emigrants.
# (c) Calculate the percentage of total emigrants for each country within that region and display the top 3 countries with
# the highest percentages.
# 9. Calculate the average number of emigrants for each year and display the years with emigration counts above the average

# %%
# Explore the unique values in the Year column
df_updated["Year"].unique()
# Out:
# array([1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#       dtype=int64)

# %%
# calulate and display the total number of emigrants for each year
df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Year
# 2015    946571
# 2016    839353
# 2022    832339
# 2014    752466
# 2012    638587
# 2019    625876
# 2013    622714
# 2017    496286
# 2011    456893
# 2008    430314
# Name: No. of Emigrants, dtype: int64

# %%
# identify and display the year with the highest number of emigrants
highest_emigrants = df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).index[0]
highest_emigrants
# Out:
# 2015

# %%
# calculate the percentage of total emigrants for each year and display the top 5 years with the highest percentages
total_emigrants = df_updated["No. of Emigrants"].sum()
total_emigrants
# Out:
# 12049891

# %%
df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10) / total_emigrants * 100
# Out:
# Year
# 2015    7.855432
# 2016    6.965648
# 2022    6.907440
# 2014    6.244588
# 2012    5.299525
# 2019    5.194039
# 2013    5.167798
# 2017    4.118593
# 2011    3.791677
# 2008    3.571103
# Name: No. of Emigrants, dtype: float64

# %%
# calulate the top three years with the highest number of emigrants highest percentage of total emigrants
df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).head(3) / total_emigrants * 100
# Out:
# Year
# 2015    7.855432
# 2016    6.965648
# 2022    6.907440
# Name: No. of Emigrants, dtype: float64

# %%
# plot a line chart showing trend the total number of emigrants for over year
df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10).plot(kind= "line", figsize=(15,6), color = "green")
# Out:
# <Axes: xlabel='Year'>

# %%
# Explore and display any interesting patterns or insights you can find in the data regarding year-wise emigration.
df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Year
# 2015    946571
# 2016    839353
# 2022    832339
# 2014    752466
# 2012    638587
# 2019    625876
# 2013    622714
# 2017    496286
# 2011    456893
# 2008    430314
# Name: No. of Emigrants, dtype: int64

# %%
# 7. For the year with the highest number of emigrants:
# identify and display the top 5 destination countries

highest_emigrants = df_updated.groupby(["Year"])["No. of Emigrants"].sum().sort_values(ascending=False).index[0]
highest_emigrants
# Out:
# 2015

# %%
# identify and display the top 5 destination regions

df_updated[df_updated["Year"] == highest_emigrants].groupby(["Destination Region"])["No. of Emigrants"].sum().sort_values(ascending=False).head(5)
# Out:
# Destination Region
# Middle East       920667
# Southeast Asia     20369
# Others              2208
# Europe              1291
# Africa              1207
# Name: No. of Emigrants, dtype: int64

# %%
# 8. For the top destination region in the highest emigration year:
# (a) Calculate and display the total number of emigrants for each country within that region.

df_updated[df_updated["Year"] == highest_emigrants].groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(10)
# Out:
# Destination Country
# Saudi Arabia            522750
# United Arab Emirates    326986
# Oman                     47788
# Malaysia                 20216
# Qatar                    12741
# Bahrain                   9029
# Others                    2206
# Iraq                       709
# Cyprus                     500
# Sudan                      494
# Name: No. of Emigrants, dtype: int64

# %%
# (b) Identify and display the country with the highest number of emigrants.
# (c) Calculate the percentage of total emigrants for each country within that region and display the top 3 countries with the highest percentages.

total_emigrants = df_updated["No. of Emigrants"].sum()
total_emigrants
# Out:
# 12049891

# %%
# 9. Calculate the average number of emigrants for each year and display the years with emigration counts above the average
average_emigrants = df_updated.groupby(["Year"])["No. of Emigrants"].mean()
average_emigrants
# Out:
# Year
# 1981     2943.865385
# 1982     2644.903846
# 1983     2308.288462
# 1984     1798.846154
# 1985     1583.326923
# 1986     1115.423077
# 1987     1272.807692
# 1988     1568.173077
# 1989     1843.519231
# 1990     2188.096154
# 1991     2746.500000
# 1992     3682.807692
# 1993     2971.711538
# 1994     2133.384615
# 1995     2250.923077
# 1996     2300.557692
# 1997     2865.942308
# 1998     1936.653846
# 1999     1501.788462
# 2000     2071.788462
# 2001     2460.173077
# 2002     2835.038462
# 2003     4116.134615
# 2004     3342.769231
# 2005     2733.365385
# 2006     3522.903846
# 2007     5519.865385
# 2008     8275.269231
# 2009     7760.153846
# 2010     6978.923077
# 2011     8786.403846
# 2012    12280.519231
# 2013    11975.269231
# 2014    14470.500000
# 2015    18203.288462
# 2016    16141.403846
# 2017     9543.961538
# 2018     7354.596154
# 2019    12036.076923
# 2020     4331.019231
# 2021     5543.846154
# 2022    15413.685185
# 2023     3641.314815
# ...

# %%
# 10. Calculate the average number of emigrants for each destination region and display the regions with emigration counts above the average
average_emigrants = df_updated.groupby(["Destination Region"])["No. of Emigrants"].mean()
average_emigrants
# Out:
# Destination Region
# Africa              122.939276
# Central Asia         25.465116
# East Asia           166.302326
# Europe              175.156682
# Middle East       20889.499106
# North America       177.116279
# Others              472.465116
# Southeast Asia      957.682171
# Name: No. of Emigrants, dtype: float64

# %%
# create a pie chart all the destination regions

df_updated.groupby(["Destination Region"])["No. of Emigrants"].sum().plot(kind="pie", figsize=(15,10), autopct="%1.1f%%", startangle=90, shadow=True, fontsize=14)
plt.title("Pie Chart of Destination Regions", fontsize=16)
plt.axis("equal")
plt.show()

# %%
# create a pie chart of the top 5 destination regions
df_updated.groupby(["Destination Region"])["No. of Emigrants"].sum().sort_values(ascending=False).head(5).plot(kind="pie", figsize=(15,10), autopct="%1.1f%%", startangle=90, shadow=True, fontsize=14)
# Out:
# <Axes: ylabel='No. of Emigrants'>

# %%
# create a pie chart of the top 5 destination countries
df_updated.groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(5).plot(kind="pie", figsize=(15,10), autopct="%1.1f%%", startangle=90, shadow=True, fontsize=14)
# Out:
# <Axes: ylabel='No. of Emigrants'>

# %%
# create a pie chart of the top 5 destination countries in the top destination region
df_updated[df_updated["Destination Region"] == top_destination_region].groupby(["Destination Country"])["No. of Emigrants"].sum().sort_values(ascending=False).head(5).plot(kind="pie", figsize=(15,10), autopct="%1.1f%%", startangle=90, shadow=True, fontsize=14)
# Out:
# <Axes: ylabel='No. of Emigrants'>

# %%
# create a scatter plot of the number of emigrants against the year
df_updated.plot(kind="scatter", x="Year", y="No. of Emigrants", figsize=(15,10), color="green")
plt.title("Scatter Plot of Emigrants against Year", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Emigrants", fontsize=14)
plt.show()
